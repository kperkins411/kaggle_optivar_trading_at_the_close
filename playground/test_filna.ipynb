# %%
import pandas as pd
import numpy as np
import optivarfuncs as of
df=of.getdf(stocks=[0,1,2,3,4])
df.sort_values(by=['date_id','seconds_in_bucket'],inplace=True)
df
# Out:
#     stock_id  date_id  far_price  near_price  seconds_in_bucket  target
# 0          0      0.0        NaN         NaN                  0       0
# 4          1      0.0        NaN         NaN                  0       4
# 8          2      0.0        NaN         NaN                  0       8
# 12         3      0.0        NaN         NaN                  0      12
# 16         4      0.0        NaN         NaN                  0      16
# 1          0      0.0        NaN         NaN                  1       1
# 5          1      0.0        NaN         NaN                  1       5
# 9          2      0.0        NaN         NaN                  1       9
# 13         3      0.0        NaN         NaN                  1      13
# 17         4      0.0        NaN         NaN                  1      17
# 2          0      0.0       20.0        21.0                  2       2
# 6          1      0.0       60.0        61.0                  2       6
# ...

# %%
df1=df.sort_values(by=['stock_id','date_id'])

# %%
df1
# Out:
#     stock_id  date_id  far_price  near_price  seconds_in_bucket  target
# 0          0      0.0        NaN         NaN                  0       0
# 1          0      0.0        NaN         NaN                  1       1
# 2          0      0.0       20.0        21.0                  2       2
# 3          0      0.0       30.0        31.0                  3       3
# 60         0      3.0        NaN         NaN                  0      60
# 61         0      3.0        NaN         NaN                  1      61
# 62         0      3.0      620.0       621.0                  2      62
# 63         0      3.0      630.0       631.0                  3      63
# 80         0      4.0        NaN         NaN                  0      80
# 81         0      4.0        NaN         NaN                  1      81
# 82         0      4.0      820.0       821.0                  2      82
# 83         0      4.0      830.0       831.0                  3      83
# ...

# %%
df1.iloc[0]

# # importing pandas as pd
# import pandas as pd
  
# # dictionary of lists
# dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
#         'degree': ["MBA", "BCA", "M.Tech", "MBA"],
#         'score':[90, 40, 80, 98]}
 
# # creating a dataframe with boolean index  
# df = pd.DataFrame(dict, index = [True, False, True, False])
 
# # accessing a dataframe using .iloc[] function 
# print(df.iloc[0])
# Out:
# stock_id             0.0
# date_id              0.0
# far_price            NaN
# near_price           NaN
# seconds_in_bucket    0.0
# target               0.0
# Name: 0, dtype: float64

# %%
df.far_price=df.far_price.interpolate(method='linear')

# %%
for index, row in df.iterrows():
    print(row["near_price"])
# Out:
# nan
# nan
# 21.0
# 31.0
# nan
# nan
# 621.0
# 631.0
# nan
# nan
# 821.0
# 831.0
# nan
# nan
# 61.0
# 71.0
# nan
# nan
# 661.0
# 671.0
# nan
# nan
# 861.0
# 871.0
# nan
# nan
# 101.0
# 111.0
# nan
# nan
# 701.0
# 711.0
# nan
# nan
# 901.0
# 911.0
# nan
# nan
# 141.0
# 151.0
# nan
# nan
# 741.0
# 751.0
# nan
# nan
# 941.0
# 951.0
# nan
# nan
# 181.0
# 191.0
# nan
# nan
# 781.0
# 791.0
# nan
# nan
# 981.0
# 991.0
